# %%
import gen_randomnet as rdnet

# %%
ER_a = rdnet.networkER_w_3Dpos(5,5,5)
ER_b = rdnet.networkER_w_3Dpos(5,5,3)

intd_ER = rdnet.intd_random_net(ER_a,ER_b)

rdnet.intdNetworkDraw(intd_ER)

# %%
BA_a = rdnet.networkSF_w_3Dpos_BA(10,1,5)
BA_b = rdnet.networkSF_w_3Dpos_BA(10,1,3)

intd_BA = rdnet.intd_random_net(BA_a,BA_b)

rdnet.intdNetworkDraw(intd_BA)

# %%
PowerL_a = rdnet.networkSF_w_3Dpos_PowerL(500,3,5)
PowerL_b = rdnet.networkSF_w_3Dpos_PowerL(500,3,3)

intd_PowerL = rdnet.intd_random_net(PowerL_a,PowerL_b)

rdnet.intdNetworkDraw(intd_PowerL)
# Out:
# Generate Scale-Free Network based on given powerLaw parameters. Last gamma: 2.9722109074429337
# Generate Scale-Free Network based on given powerLaw parameters. Last gamma: 2.9849974745702186
