# %%
# %load_ext autoreload
# %autoreload

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.attack import *
from src.create import *
from src.measure import *

# %%
n_file = "../data/vertex/vertex.csv"
e_file = "../data/edge/edge.csv"
edges_crosslayer = "../data/edge/edge_m_tr.csv"

ParisResult_t5 = generate_pinf_real(n_file, e_file, edges_crosslayer, t=5)

np.savetxt('./results/ParisResult_t5.csv', ParisResult_t5, delimiter=',')
# Out:
# ...Interdependent Graph Generate Done! 0:00:00.275896
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.000000' is Done! 0:00:00.139888
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  125
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.052632' is Done! 0:00:00.472760
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.105263' is Done! 0:00:00.807166
# giant component :  129
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.157895' is Done! 0:00:01.029129
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.210526' is Done! 0:00:01.174958
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.263158' is Done! 0:00:01.442509
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.315789' is Done! 0:00:01.595742
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.368421' is Done! 0:00:01.666030
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.421053' is Done! 0:00:01.796361
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.473684' is Done! 0:00:01.980298
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.526316' is Done! 0:00:02.288333
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.578947' is Done! 0:00:02.388536
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.631579' is Done! 0:00:02.441371
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.684211' is Done! 0:00:02.750368
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.736842' is Done! 0:00:02.966599
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.789474' is Done! 0:00:02.999525
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.842105' is Done! 0:00:02.945185
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.894737' is Done! 0:00:03.056350
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '0.947368' is Done! 0:00:03.935959
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# giant component :  120
# giant component init :  544
# ...test: '1.000000' is Done! 0:00:03.959906

# %%
ParisResult_t5 = np.loadtxt('./results/ParisResult_t5.csv',delimiter=",")

for i in ParisResult_t5[1]:
    print(i)

# plt.scatter(ParisResult_t5[0], ParisResult_t5[1])

# plot_pinf([ParisResult_t5], 4, labels = ["Paris Metro"], path="../notebooks/figure/Paris_pinf.png", p_theory=False)
# Out:
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.22058823529411767
# 0.23455882352941176
# 0.22058823529411767

# %%
SFn2000g23 = generate_pinf_SF(50, 2.3)  # SF model, node=500, gamma=2.3

# %%
print(SFn2000g23)
plt.scatter(SFn2000g23[0],SFn2000g23[1])
# Out:
# (array([0.1       , 0.14210526, 0.18421053, 0.22631579, 0.26842105,
#        0.31052632, 0.35263158, 0.39473684, 0.43684211, 0.47894737,
#        0.52105263, 0.56315789, 0.60526316, 0.64736842, 0.68947368,
#        0.73157895, 0.77368421, 0.81578947, 0.85789474, 0.9       ]), array([0.02 , 0.02 , 0.032, 0.028, 0.056, 0.06 , 0.064, 0.112, 0.052,
#        0.056, 0.128, 0.324, 0.4  , 0.36 , 0.524, 0.656, 0.688, 0.82 ,
#        0.82 , 0.884]))

# %%
SFn2000g23 = generate_pinf_SF(50, 2.3)  # SF model, node=500, gamma=2.3
SFn2000g27 = generate_pinf_SF(50, 2.7)  # SF model, node=500, gamma=2.7
SFn2000g3 = generate_pinf_SF(2000, 3)  # SF model, node=500, gamma=3

# plot_pinf([SFn2000g23, SFn2000g27, SFn2000g3], 4, ["SF, n=2000, l=2.3", "SF, n=2000, l=2.7", "SF, n=2000, l=3"],
#               path="../notebooks/figure/SF_pinf.png", p_theory=False)

np.savetxt('./results/Sfn2000_23.csv', SFn2000g23, delimiter=',')
np.savetxt('./results/Sfn2000_27.csv', SFn2000g27, delimiter=',')
np.savetxt('./results/SFn2000_3.csv', SFn2000g3, delimiter=',')
