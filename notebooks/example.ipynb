# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.attack import *
from src.create import *
from src.measure import *

# %%
ERn250k4 = generate_pinf_ER(250, 4)  # ER model, node=250, k=4

# save and load the results
np.savetxt('./results/ERn250k4.csv', ERn250k4, delimiter=',')
ERn250k4 = np.loadtxt('./results/ERn250k4.csv',delimiter=",")

plot_pinf([ERn250k4], 4, ["ER, n=250, k=4", "ER, n=1000, k=4", "ER, n=2000, k=4"],
              path="../notebooks/figure/ER_pinf.png", p_theory=False)
# Out:
# ...Interdependent Graph Generate Done! 0:00:00.484632
# ...test: '0.100000' is Done! 0:00:02.851743
# ...test: '0.188889' is Done! 0:00:03.017163
# ...test: '0.277778' is Done! 0:00:02.611334
# ...test: '0.366667' is Done! 0:00:02.841542
# ...test: '0.455556' is Done! 0:00:05.862260
# ...test: '0.544444' is Done! 0:00:02.752693
# ...test: '0.633333' is Done! 0:00:02.655003
# ...test: '0.722222' is Done! 0:00:02.412544
# ...test: '0.811111' is Done! 0:00:01.502277
# ...test: '0.900000' is Done! 0:00:01.085881
