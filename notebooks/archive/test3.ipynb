# %%
# %load_ext autoreload
# %autoreload

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.attack import *
from src.create import *
from src.measure import *

# %%
n_file = "../data/vertex/vertex.csv"
e_file = "../data/edge/edge.csv"
edges_crosslayer = "../data/edge/edge_m_tr.csv"

ParisResult_t5 = generate_pinf_real(n_file, e_file, edges_crosslayer, t=5)

np.savetxt('./results/ParisResult_t5.csv', ParisResult_t5, delimiter=',')
# Out:
# ...Interdependent Graph Generate Done! 0:00:00.252139
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# ...test: '0.000000' is Done! 0:00:02.707451
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# ...test: '0.052632' is Done! 0:00:02.495567
# giant component :  122
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  122
# giant component init :  517
# giant component real :  517
# ...test: '0.105263' is Done! 0:00:02.415207
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# ...test: '0.157895' is Done! 0:00:02.330134
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  122
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# ...test: '0.210526' is Done! 0:00:02.283307
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  126
# giant component init :  517
# giant component real :  517
# giant component :  124
# giant component init :  517
# giant component real :  517
# ...test: '0.263158' is Done! 0:00:02.155084
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  122
# giant component init :  517
# giant component real :  517
# giant component :  122
# giant component init :  517
# giant component real :  517
# giant component :  130
# giant component init :  517
# giant component real :  517
# giant component :  122
# giant component init :  517
# giant component real :  517
# ...test: '0.315789' is Done! 0:00:02.061431
# giant component :  123
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  124
# giant component init :  517
# giant component real :  517
# giant component :  123
# giant component init :  517
# giant component real :  517
# giant component :  124
# giant component init :  517
# giant component real :  517
# ...test: '0.368421' is Done! 0:00:01.964444
# giant component :  132
# giant component init :  517
# giant component real :  517
# giant component :  131
# giant component init :  517
# giant component real :  517
# giant component :  123
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  123
# giant component init :  517
# giant component real :  517
# ...test: '0.421053' is Done! 0:00:01.905883
# giant component :  144
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  142
# giant component init :  517
# giant component real :  517
# giant component :  125
# giant component init :  517
# giant component real :  517
# ...test: '0.473684' is Done! 0:00:01.771822
# giant component :  141
# giant component init :  517
# giant component real :  517
# giant component :  146
# giant component init :  517
# giant component real :  517
# giant component :  179
# giant component init :  517
# giant component real :  517
# giant component :  143
# giant component init :  517
# giant component real :  517
# giant component :  123
# giant component init :  517
# giant component real :  517
# ...test: '0.526316' is Done! 0:00:01.742814
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  165
# giant component init :  517
# giant component real :  517
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  145
# giant component init :  517
# giant component real :  517
# giant component :  142
# giant component init :  517
# giant component real :  517
# ...test: '0.578947' is Done! 0:00:01.600665
# giant component :  217
# giant component init :  517
# giant component real :  517
# giant component :  192
# giant component init :  517
# giant component real :  517
# giant component :  174
# giant component init :  517
# giant component real :  517
# giant component :  180
# giant component init :  517
# giant component real :  517
# giant component :  153
# giant component init :  517
# giant component real :  517
# ...test: '0.631579' is Done! 0:00:01.541500
# giant component :  120
# giant component init :  517
# giant component real :  517
# giant component :  137
# giant component init :  517
# giant component real :  517
# giant component :  135
# giant component init :  517
# giant component real :  517
# giant component :  202
# giant component init :  517
# giant component real :  517
# giant component :  135
# giant component init :  517
# giant component real :  517
# ...test: '0.684211' is Done! 0:00:01.263032
# giant component :  204
# giant component init :  517
# giant component real :  517
# giant component :  297
# giant component init :  517
# giant component real :  517
# giant component :  184
# giant component init :  517
# giant component real :  517
# giant component :  265
# giant component init :  517
# giant component real :  517
# giant component :  212
# giant component init :  517
# giant component real :  517
# ...test: '0.736842' is Done! 0:00:01.095283
# giant component :  292
# giant component init :  517
# giant component real :  517
# giant component :  287
# giant component init :  517
# giant component real :  517
# giant component :  324
# giant component init :  517
# giant component real :  517
# giant component :  294
# giant component init :  517
# giant component real :  517
# giant component :  344
# giant component init :  517
# giant component real :  517
# ...test: '0.789474' is Done! 0:00:00.962228
# giant component :  253
# giant component init :  517
# giant component real :  517
# giant component :  325
# giant component init :  517
# giant component real :  517
# giant component :  345
# giant component init :  517
# giant component real :  517
# giant component :  322
# giant component init :  517
# giant component real :  517
# giant component :  407
# giant component init :  517
# giant component real :  517
# ...test: '0.842105' is Done! 0:00:00.852589
# giant component :  376
# giant component init :  517
# giant component real :  517
# giant component :  376
# giant component init :  517
# giant component real :  517
# giant component :  410
# giant component init :  517
# giant component real :  517
# giant component :  414
# giant component init :  517
# giant component real :  517
# giant component :  425
# giant component init :  517
# giant component real :  517
# ...test: '0.894737' is Done! 0:00:00.610398
# giant component :  461
# giant component init :  517
# giant component real :  517
# giant component :  451
# giant component init :  517
# giant component real :  517
# giant component :  476
# giant component init :  517
# giant component real :  517
# giant component :  480
# giant component init :  517
# giant component real :  517
# giant component :  468
# giant component init :  517
# giant component real :  517
# ...test: '0.947368' is Done! 0:00:00.369863
# giant component :  517
# giant component init :  517
# giant component real :  517
# giant component :  517
# giant component init :  517
# giant component real :  517
# giant component :  517
# giant component init :  517
# giant component real :  517
# giant component :  517
# giant component init :  517
# giant component real :  517
# giant component :  517
# giant component init :  517
# giant component real :  517
# ...test: '1.000000' is Done! 0:00:00.094975

# %%
ParisResult_t5 = np.loadtxt('./results/ParisResult_t5.csv',delimiter=",")

for i in ParisResult_t5[1]:
    print(i)

plt.scatter(ParisResult_t5[0], ParisResult_t5[1])

# plot_pinf([ParisResult_t5], 4, labels = ["Paris Metro"], path="../notebooks/figure/Paris_pinf.png", p_theory=False)
# Out:
# 0.23210831721470018
# 0.23210831721470018
# 0.2336557059961315
# 0.23210831721470018
# 0.23288201160541586
# 0.23597678916827852
# 0.23829787234042552
# 0.23752417794970984
# 0.24332688588007736
# 0.2518375241779497
# 0.28317214700193427
# 0.2676982591876209
# 0.3543520309477756
# 0.28201160541586073
# 0.4495164410058027
# 0.5961315280464217
# 0.6390715667311412
# 0.7740812379110251
# 0.9036750483558993
# 1.0

# %%
SFn2000g23 = generate_pinf_SF(50, 2.3)  # SF model, node=500, gamma=2.3

# %%
print(SFn2000g23)
plt.scatter(SFn2000g23[0],SFn2000g23[1])
# Out:
# (array([0.1       , 0.14210526, 0.18421053, 0.22631579, 0.26842105,
#        0.31052632, 0.35263158, 0.39473684, 0.43684211, 0.47894737,
#        0.52105263, 0.56315789, 0.60526316, 0.64736842, 0.68947368,
#        0.73157895, 0.77368421, 0.81578947, 0.85789474, 0.9       ]), array([0.02 , 0.02 , 0.032, 0.028, 0.056, 0.06 , 0.064, 0.112, 0.052,
#        0.056, 0.128, 0.324, 0.4  , 0.36 , 0.524, 0.656, 0.688, 0.82 ,
#        0.82 , 0.884]))

# %%
SFn2000g23 = generate_pinf_SF(50, 2.3)  # SF model, node=500, gamma=2.3
SFn2000g27 = generate_pinf_SF(50, 2.7)  # SF model, node=500, gamma=2.7
SFn2000g3 = generate_pinf_SF(2000, 3)  # SF model, node=500, gamma=3

# plot_pinf([SFn2000g23, SFn2000g27, SFn2000g3], 4, ["SF, n=2000, l=2.3", "SF, n=2000, l=2.7", "SF, n=2000, l=3"],
#               path="../notebooks/figure/SF_pinf.png", p_theory=False)

np.savetxt('./results/Sfn2000_23.csv', SFn2000g23, delimiter=',')
np.savetxt('./results/Sfn2000_27.csv', SFn2000g27, delimiter=',')
np.savetxt('./results/SFn2000_3.csv', SFn2000g3, delimiter=',')
